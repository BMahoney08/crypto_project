# %%
import pandas as pd
import datetime as date

# %%
btc_d = pd.read_csv(r'Data\BTC\BTC_D.csv')

# %%
pd.read_csv(r'Data\BTC\BTC_D.csv')
# Out:
#             time      open      high       low     close        Volume  \
# 0     1434844800    246.08    246.98    242.00    244.66   3632.000000
# 1     1434931200    244.66    248.50    243.86    247.50   5543.000000
# 2     1435017600    247.48    248.06    243.01    244.52   5264.000000
# 3     1435104000    244.54    244.92    239.51    240.04   5281.000000
# 4     1435190400    240.14    243.44    239.91    242.44   5637.000000
# ...          ...       ...       ...       ...       ...           ...
# 2319  1635206400  63081.96  63290.49  59837.07  60337.62  12046.433399
# 2320  1635292800  60333.19  61488.00  58100.00  58455.47  18714.237237
# 2321  1635379200  58462.73  62477.47  57653.88  60591.65  18592.151615
# 2322  1635465600  60591.63  62974.00  60188.73  62276.72  15445.295737
# 2323  1635552000  62287.95  62379.20  60763.25  61279.47   4751.636541
#
#          Volume MA      Volume.1   Volume MA.1        RSI  ...  \
# ...

# %%
btc_d.apply()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2324 entries, 0 to 2323
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   time                         2324 non-null   int64
#  1   open                         2324 non-null   float64
#  2   high                         2324 non-null   float64
#  3   low                          2324 non-null   float64
#  4   close                        2324 non-null   float64
#  5   Volume                       2324 non-null   float64
#  6   Volume MA                    2324 non-null   float64
#  7   Volume.1                     2324 non-null   float64
#  8   Volume MA.1                  2324 non-null   float64
#  9   RSI                          2324 non-null   float64
#  10  OnBalanceVolume              2324 non-null   float64
#  11  Accumulation/Distribution    2324 non-null   float64
# ...
